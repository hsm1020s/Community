# %%
기대감 만족감 설명 긍부정 

상품소개페이지 

FP튜닝?
further pretraining 

이미지 단어 요약 (OCR성능에 좌우) 80~85%

=======================
하이퍼클로바X 200%활용하기
CoT CHain of thought 프롬프트 방법론 
모델이커지면 속도가느리다 그치만 추론능력 좋아진다 

COT 단점 업무정보,업무순서,모든상황에 X

자연어로된걸 벡터로만든게 벡터DB 

자연어를 쿼리로 바꿔서 질문 -> 질문을쪼개는작업 ->쿼리 날릴지 안날릴지 여부 -> 자연어를 컬럼명으로 변경?검색?
권한있는사람만 질의가능 -> 특정정보 


튜닝은 언어모델에게 원하는 출력스타일을 연습시키는것 

답변할떄 토큰뒤에 확률을 가공? 

SFT 수퍼바이저드 라인튜닝 

RLHF방법-> 지피티 좋아요싫어요로 판단 

싱글턴,멀티턴 학습데이터셋 

용어-> jsonl 

웬만하면 프롬프트에서 해결->튜닝 권장하지않음 ->노가다임 

RAG 기술-> 미학습내용에대한 답변 

질의->벡터로바꿈 ->서치엔진으로 비슷한거 찾아서 LLM한테 이거가지고 만들어 라고함 ->출처도 넣음 뭘근거로했는지 

용어->쿼리 트리, 청크 
랭체인으로 전처리? 

세그멘테이션API(자르는거) 인베딩API
쿼드란트 포스트그레스큐엘  


=====================
질문 

수학
최신논문 -> 쓸떄의 ~~관점에서 쓰고싶다 
밀버스 코드란트 DB 
데이터마트 
로봇은 클라우드연결 해서 움직임 

sci참조랭킹
